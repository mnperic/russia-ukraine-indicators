# %%
# Import dependencies and setup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as matplotlib
import matplotlib.dates as matplotlibdates
import datetime
from matplotlib.dates import date2num

# %%
# Read .csv files and store as DataFrames
inflation_mom_path = "Resources/inflation_month_over_month.csv"
inflation_mom_df = pd.read_csv(inflation_mom_path)

inflation_monthly_path = "Resources/inflation_monthly.csv"
inflation_monthly_df = pd.read_csv(inflation_monthly_path)

inflation_yoy_path = "Resources/inflation_year_over_year.csv"
inflation_yoy_df = pd.read_csv(inflation_yoy_path)

gas_dutch_price_path = "Resources/gas_dutch.csv"
gas_dutch_df = pd.read_csv(gas_dutch_price_path)

gas_nymex_price_path = "Resources/nymex_natural_gas.csv"
gas_nymex_df = pd.read_csv(gas_nymex_price_path)

oil_espo_path = "Resources/oil_espo.csv"
oil_espo_df = pd.read_csv(oil_espo_path)

oil_sokol_path = "Resources/oil_sokol.csv"
oil_sokol_df = pd.read_csv(oil_sokol_path)

commodity_prices_path = "Resources/commodity_prices.csv"
commodity_prices_df = pd.read_csv(commodity_prices_path)

reserves_russia_path = "Resources/russia_reserves.csv"
reserves_russia_df = pd.read_csv(reserves_russia_path)

reserves_ukraine_path = "Resources/ukraine_reserves.csv"
reserves_ukraine_df = pd.read_csv(reserves_ukraine_path)

gdp_russia_path = "Resources/russia_gdp.csv"
gdp_russia_df = pd.read_csv(gdp_russia_path)

gdp_ukraine_path = "Resources/ukraine_gdp.csv"
gdp_ukraine_df = pd.read_csv(gdp_ukraine_path)

# %%
# Preview inflation_mom
inflation_mom_df.head()
# Out:
#      date  rate
# 0  1/1/21  0.67
# 1  1/2/21  0.78
# 2  1/3/21  0.66
# 3  1/4/21  0.58
# 4  1/5/21  0.74

# %%
# Preview inflation_monthly
inflation_monthly_df.head()
# Out:
#      date  rate
# 0  1/1/21   5.2
# 1  1/2/21   5.7
# 2  1/3/21   5.8
# 3  1/4/21   5.5
# 4  1/5/21   6.0

# %%
# Preview inflation_yoy
inflation_yoy_df.head()
# Out:
#      date  rate
# 0  1/1/21  5.19
# 1  1/2/21  5.67
# 2  1/3/21  5.78
# 3  1/4/21  5.52
# 4  1/5/21  6.01

# %%
# Preview gas_dutch
gas_dutch_df.head()
# Out:
#      date  price_eur_mw  exchange_rate  price_usd_mw  exchange_rate.1  \
# 0  1/2/22         76.17           1.11       84.5487              1.7
# 1  2/2/22         77.35           1.11       85.8585              1.7
# 2  3/2/22         80.22           1.11       89.0442              1.7
# 3  4/2/22         82.65           1.11       91.7415              1.7
# 4  7/2/22         79.59           1.11       88.3449              1.7
#
#    price_usd_barrel
# 0         143.73279
# 1         145.95945
# 2         151.37514
# 3         155.96055
# 4         150.18633

# %%
# Preview gas_nymex
gas_nymex_df.head()
# Out:
#         date  price_usd_mmbtu  exchange_rate  price_usd_barrel
# 0 2022-02-01             4.57           5.56           25.4092
# 1 2022-02-02             5.04           5.56           28.0224
# 2 2022-02-03             4.72           5.56           26.2432
# 3 2022-02-04             4.49           5.56           24.9644
# 4 2022-02-07             4.19           5.56           23.2964

# %%
# Preview oil_espo
oil_espo_df.head()
# Out:
#         date  price_usd
# 0 2022-02-04      89.70
# 1 2022-02-06      92.37
# 2 2022-02-07      93.01
# 3 2022-02-08      92.36
# 4 2022-02-09      91.51

# %%
# Preview oil_sokol
oil_sokol_df.head()
# Out:
#         date  price_usd
# 0 2022-02-01      90.11
# 1 2022-02-02      89.99
# 2 2022-02-03      89.63
# 3 2022-02-04      91.82
# 4 2022-02-07      93.80

# %%
# Preview commodity_prices
commodity_prices_df.head()
# Out:
#      commodity  yoy_percent
# 0    Crude Oil        77.71
# 1    Brent Oil        72.57
# 2  Natural Gas        75.16
# 3     Gasoline        69.61
# 4  Heating Oil        91.06

# %%
# Preview reseres_russia
reserves_russia_df.head()
# Out:
#    year  price_usd
# 0  2010     479.22
# 1  2011     497.41
# 2  2012     537.81
# 3  2013     509.69
# 4  2014     386.21

# %%
# Preview reseres_ukraine
reserves_ukraine_df.head()
# Out:
#    year  price_usd
# 0  2010      34.57
# 1  2011      31.78
# 2  2012      24.55
# 3  2013      20.41
# 4  2014       7.53

# %%
# Preview gdp_russia
gdp_russia_df.head()
# Out:
#    year  price_usd
# 0  2010       1.52
# 1  2011       2.04
# 2  2012       2.20
# 3  2013       2.29
# 4  2014       2.05

# %%
# Preview gdp_ukraine
gdp_ukraine_df.head()
# Out:
#    year  price_usd
# 0  2010     141.21
# 1  2011     169.33
# 2  2012     182.59
# 3  2013     190.49
# 4  2014     133.50

# %%
# Convert all 'date' columns to datetime=
inflation_mom_df['date'] = pd.to_datetime(inflation_mom_df['date'], format='%d/%m/%y')
inflation_monthly_df['date'] = pd.to_datetime(inflation_monthly_df['date'], format='%d/%m/%y')
inflation_yoy_df['date'] = pd.to_datetime(inflation_yoy_df['date'], format='%d/%m/%y')
gas_dutch_df['date'] = pd.to_datetime(gas_dutch_df['date'], format='%d/%m/%y')
gas_nymex_df['date'] = pd.to_datetime(gas_nymex_df['date'], format='%d/%m/%y')
oil_espo_df['date'] = pd.to_datetime(oil_espo_df['date'], format='%d/%m/%y')
oil_sokol_df['date'] = pd.to_datetime(oil_sokol_df['date'], format='%d/%m/%y')
reserves_russia_df['year'] = pd.to_datetime(reserves_russia_df['year'], format='%Y')
reserves_ukraine_df['year'] = pd.to_datetime(reserves_ukraine_df['year'], format='%Y')
gdp_russia_df['year'] = pd.to_datetime(gdp_russia_df['year'], format='%Y')
gdp_ukraine_df['year'] = pd.to_datetime(gdp_ukraine_df['year'], format='%Y')

# %%
# Plotting – inflation_mom

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.bar(inflation_mom_df['date'],inflation_mom_df['rate'], width=25, color='blue', alpha=0.5)
plt.plot(inflation_mom_df['date'], inflation_mom_df['rate'], color='orange', linewidth=3)

# Labels
plt.title("Inflation (Month over Month), Russia, Jan 2021 – Jan 2022", fontdict = font_1)
plt.xlabel("Month", fontdict = font_2)
plt.ylabel("Growth Rate (%)", fontdict = font_2)

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/russia-energy-inflation/Images/inflation_mom.png", dpi=300)
plt.show()

# %%
# Plotting – inflation_yoy

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.bar(inflation_yoy_df['date'], inflation_yoy_df['rate'], width=25, color='blue', alpha=0.5)
plt.plot(inflation_yoy_df['date'], inflation_yoy_df['rate'], color='orange', linewidth=3)

# Labels
plt.title("Inflation (Year over Year), Russia, Jan 2021 – Jan 2022", fontdict = font_1)
plt.xlabel("Month", fontdict = font_2)
plt.ylabel("Growth Rate (%)", fontdict = font_2)

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/russia-energy-inflation/Images/inflation_yoy.png", dpi=300)
plt.show()

# %%
# Plotting – inflation_monthly

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.bar(inflation_monthly_df['date'], inflation_monthly_df['rate'], width=25, color='blue', alpha=0.5)
plt.plot(inflation_monthly_df['date'], inflation_monthly_df['rate'], color='orange', linewidth=3)

# Labels
plt.title("Inflation – Russia, Jan 2021 – Jan 2022", fontdict = font_1)
plt.xlabel("Month", fontdict = font_2)
plt.ylabel("Rate (%)", fontdict = font_2)

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/russia-energy-inflation/Images/inflation_monthly.png", dpi=300)
plt.show()

# %%
# Plotting – Natural Gas Comparison

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(gas_dutch_df['date'], gas_dutch_df['price_usd_barrel'], color='blue', label='Dutch TTF (EUR)', linewidth=3)
plt.plot(gas_nymex_df['date'], gas_nymex_df['price_usd_barrel'], color='orange', label='NYMEX TTF (USA)', linewidth=3)
plt.legend()

# Labels
plt.title("TTF Natural Gas Prices, 2 Jan 2022 – 4 Mar 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("USD per barrel", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime.datetime(2022,2,24)), date2num(datetime.datetime(2022,3,2)), 
           label="Invasion of Ukraine", color="red", alpha=0.05)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/russia-energy-inflation/Images/natural_gas.png", dpi=300)
plt.show()

# %%
# Trim oil_sokol_df to match date range of oil_espo_df

oil_sokol_trimmed_df = oil_sokol_df.iloc[3:]
oil_sokol_trimmed_df
# Out:
#          date  price_usd
# 3  2022-02-04      91.82
# 4  2022-02-07      93.80
# 5  2022-02-08      93.07
# 6  2022-02-09      91.28
# 7  2022-02-10      92.55
# 8  2022-02-14      97.37
# 9  2022-02-15      97.31
# 10 2022-02-16      95.08
# 11 2022-02-17      95.12
# 12 2022-02-18      94.33
# 13 2022-02-21      94.69
# 14 2022-02-22      97.84
# 15 2022-02-24     101.32
# 16 2022-02-25      99.31
# 17 2022-02-28     100.80
# 18 2022-03-01      97.49
# 19 2022-03-02      98.68

# %%
# Plotting – Oil

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(oil_espo_df['date'], oil_espo_df['price_usd'], color='blue', label='ESPO', linewidth=3)
plt.plot(oil_sokol_trimmed_df['date'], oil_sokol_trimmed_df['price_usd'], color='orange', label='Sokol', linewidth=3)
plt.legend()

# Labels
plt.title("Russian Oil Prices, 4 Feb 2022 – 4 Mar 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("USD per barrel", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime.datetime(2022,2,24)), date2num(datetime.datetime(2022,3,2)), 
           label="Invasion of Ukraine", color="red", alpha=0.05)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/russia-energy-inflation/Images/oil.png", dpi=300)
plt.show()

# %%
# Plotting – Commodities

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.bar(commodity_prices_df['commodity'], commodity_prices_df['yoy_percent'], width=0.5, color='blue', alpha=0.5)
plt.plot(commodity_prices_df['commodity'], commodity_prices_df['yoy_percent'], color='orange', linewidth=3)

# Labels
plt.title("Commodity Prices (Year on Year), 2 Mar 2021 – 2 Mar 2022", fontdict = font_1)
plt.xlabel("Commodity", fontdict = font_2)
plt.ylabel("Return (%)", fontdict = font_2)

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/russia-energy-inflation/Images/commodity_prices.png", dpi=300)
plt.show()

# %%
# Plotting – Reserves (inc. gold)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(reserves_russia_df['year'], reserves_russia_df['price_usd'], color='blue', label='Russia', linewidth=3)
plt.plot(reserves_ukraine_df['year'], reserves_ukraine_df['price_usd'], color='orange', label='Ukraine', linewidth=3)

# Labels
plt.title("Total Reserves (including Gold), 2010 – 2020", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Price (USD Billions)", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime.datetime(2014,2,20)), date2num(datetime.datetime(2020,1,1)), 
           label="Russo-Ukrainian War", color="red", alpha=0.05)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/russia-energy-inflation/Images/reserves_russia_ukraine.png", dpi=300)
plt.show()

# %%
# Plotting – GDP

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(gdp_russia_df['year'], gdp_russia_df['price_usd'], color='blue', label='Russia', linewidth=3)
plt.plot(gdp_ukraine_df['year'], gdp_ukraine_df['price_usd'], color='orange', label='Ukraine', linewidth=3)

# Labels
plt.title("GDP, 2010 – 2020", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Price (USD Billions)", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime.datetime(2014,2,20)), date2num(datetime.datetime(2020,1,1)), 
           label="Russo-Ukrainian War", color="red", alpha=0.05)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/russia-energy-inflation/Images/gdp_russia_ukraine.png", dpi=300)
plt.show()
